# %%
import pandas as pd

#Column Name Labels
names = ['player-id', 'player-name','height', 'weight', 'college', 'birth-year', 'birth-city', 'birth-state/country']

#Loading Players.csv data set
df = pd.read_csv('Players.csv', header = None, names = names)
df.head()
df.dropna()
# Out:
#       player-id         player-name height weight  \
# 2           1.0        Cliff Barker    188     83
# 5           4.0         Ralph Beard    178     79
# 7           6.0       Charlie Black    196     90
# 8           7.0         Nelson Bobb    183     77
# 9           8.0     Jake Bornheimer    196     90
# 10          9.0        Vince Boryla    196     95
# 11         10.0           Don Boven    193     95
# 12         11.0       Harry Boykoff    208    102
# 13         12.0         Joe Bradley    190     79
# 15         14.0          Carl Braun    196     81
# 16         15.0       Frankie Brian    185     81
# 17         16.0    Price Brookfield    193     83
# 18         17.0           Bob Brown    193     92
# 20         19.0          Walt Budko    196     99
# 22         21.0        Tommy Byrnes    190     79
# 23         22.0        Bill Calhoun    190     81
# 24         23.0         Don Carlson    183     77
# 29         28.0       Leroy Chollet    188     86
# ...
